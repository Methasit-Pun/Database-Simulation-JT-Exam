# %% [markdown]
# Find out the top 10 films with largest number of actors in the FILM table. Result includes
# title and actor_count (6 points)

# %% [markdown]
# Select only the films with rating equals to ‘G’ or ‘R’, aggregate the average rental_rate, and
# max replacement_cost based on rental_duration, and show the results only for
# rental_duration >=3 in the FILM table (6 points)

# %% [markdown]
# Select rental_duration, title, rental_rate in the FILM table, and show the average rental_rate
# based on rental_duration order by rental_rate in each subgroup for each film without
# aggregation. (need to add the sentence “range between unbounded preceding and unbounded
# following”) (6 points)

# %% [markdown]
# Calculate rental_length by difference between rental_date and return_date for each rental_id
# in the RENTAL table, show the overall average rental_length in one additional column. Then
# add one column rental_duration if rental_length is longer than the average then “Long” and
# otherwise “short” (6 points)
